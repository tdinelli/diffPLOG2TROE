# %%
import jax.numpy as jnp
from diffPLOG2TROE.kinetics import Plog, CollisionEfficiency

# %% [markdown]
# ```bash
# - equation: H + O2 (+M) <=> HO2 (+M) # Adding '(+M)' is optional
#   type: linear-Burke
#   colliders:
#   - name: M
#     type: pressure-dependent-Arrhenius
#     rate-constants:
#     - {P: 1.316e-02 atm, A: 9.39968e+14, b: -2.14348e+00, Ea: 7.72730e+01}
#     - {P: 1.316e-01 atm, A: 1.07254e+16, b: -2.15999e+00, Ea: 1.30239e+02}
#     - {P: 3.947e-01 atm, A: 3.17830e+16, b: -2.15813e+00, Ea: 1.66994e+02}
#     - {P: 1.000e+00 atm, A: 7.72584e+16, b: -2.15195e+00, Ea: 2.13473e+02}
#     - {P: 3.000e+00 atm, A: 2.11688e+17, b: -2.14062e+00, Ea: 2.79031e+02}
#     - {P: 1.000e+01 atm, A: 6.53093e+17, b: -2.13213e+00, Ea: 3.87493e+02}
#     - {P: 3.000e+01 atm, A: 1.49784e+18, b: -2.10026e+00, Ea: 4.87579e+02}
#     - {P: 1.000e+02 atm, A: 3.82218e+18, b: -2.07057e+00, Ea: 6.65984e+02}
#   - name: HE
#     efficiency: {A: 3.37601e-01, b: 1.82568e-01, Ea: 3.62408e+01}
#   - name: N2
#     efficiency: {A: 1.24932e+02, b: -5.93263e-01, Ea: 5.40921e+02}
#   - name: H2
#     efficiency: {A: 3.13717e+04, b: -1.25419e+00, Ea: 1.12924e+03}
#   - name: CO2
#     efficiency: {A: 1.62413e+08, b: -2.27622e+00, Ea: 1.97023e+03}
#   - name: NH3
#     efficiency: {A: 4.97750e+00, b: 1.64855e-01, Ea: -2.80351e+02}
#   - name: H2O
#     efficiency: {A: 3.69146e+01, b: -7.12902e-02, Ea: 3.19087e+01}
# ```
#
# ```bash
# H+O2(+M)=HO2(+M)   1.000          0.000    0.000
# RPBMR  / LINEAR /
#  COLL  / AR        6.2814E+20    -1.770    642.660 /
#   PLOG / 0.10      9.6149E+17    -2.800    739.430 /
#   PLOG / 1.00      8.2354E+18    -2.780    836.070 /
#   PLOG / 10.00     4.9667E+19    -2.719    989.680 /
#   PLOG / 100.00    1.7637E+20    -2.596    1256.89 /
#  COLL  / HE        3.9936E+20    -1.720    631.600 /
#   PLOG / 0.10      8.9016E+17    -2.800    788.800 /
#   PLOG / 1.00      8.1980E+18    -2.790    889.590 /
#   PLOG / 10.00     4.3100E+19    -2.712    1002.67 /
#   PLOG / 100.00    1.3738E+20    -2.576    1232.78 /
#  COLL  / N2        4.6362E+21    -1.977    672.760 /
#   PLOG / 0.10      7.3248E+18    -3.011    793.410 /
#   PLOG / 1.00      6.4063E+19    -2.993    924.010 /
#   PLOG / 10.00     3.7158E+20    -2.926    1134.82 /
#   PLOG / 100.00    1.2397E+21    -2.794    1495.48 /
#  COLL  / H2O       1.1447E+21    -1.417    460.790 /
#   PLOG / 0.10      2.1686E+18    -2.472    687.690 /
#   PLOG / 1.00      1.5935E+19    -2.430    924.830 /
#   PLOG / 10.00     4.4494E+19    -2.272    1260.94 /
#   PLOG / 100.00    1.9898E+19    -1.901    1583.74 /
#  COLL  / CO2       3.1750E+19    -1.087    553.370 /
#   PLOG / 0.10      4.9578E+16    -2.119    681.240 /
#   PLOG / 1.00      3.3623E+17    -2.070    779.670 /
#   PLOG / 10.00     1.1054E+18    -1.937    907.630 /
#   PLOG / 100.00    1.4019E+18    -1.696    1100.28 /
#  COLL  / H2        6.0298E+21    -1.971    699.130 /
#   PLOG / 0.10      9.6838E+18    -3.007    846.490 /
#   PLOG / 1.00      7.4253E+19    -2.973    968.350 /
#   PLOG / 10.00     3.9251E+20    -2.897    1180.78 /
#   PLOG / 100.00    1.1190E+21    -2.747    1539.33 /
#  COLL  / O2        2.2651E+21    -1.954    639.920 /
#   PLOG / 0.10      3.5715E+18    -2.988    747.150 /
#   PLOG / 1.00      3.2142E+19    -2.974    862.190 /
#   PLOG / 10.00     2.0376E+20    -2.918    1042.63 /
#   PLOG / 100.00    7.9974E+20    -2.806    1362.75 /
#  COLL  / DEFAULT   6.2814E+20    -1.770    642.660 /
#   H / 1 / ! CO / 1.900 / CH4 / 2.000 / C2H6 / 3.000 /
#   PLOG / 0.10      9.6149E+17    -2.800    739.430 /
#   PLOG / 1.00      8.2354E+18    -2.780    836.070 /
#   PLOG / 10.00     4.9667E+19    -2.719    989.680 /
#   PLOG / 100.00    1.7637E+20    -2.596    1256.89 /
#
# ```

# %%
help(Plog)

# %%
default_collider = Plog(
    name="H+O2(+M)=HO2(+M)",
    parameters={
        0.10: {"A": 9.6149E+17, "n": -2.800, "Ea": 739.430},
        1.00: {"A": 8.2354E+18, "n": -2.780, "Ea": 836.070},
        10.00: {"A": 4.9667E+19, "n": -2.719, "Ea": 989.680},
        100.00: {"A": 1.7637E+20, "n": -2.596, "Ea": 1256.89},
    }
)

reaction_ar =

explicit_rate_constants = {
    "Ar": reaction_ar,
}

# rate_constant = LinearMixtureRule(
#     default_rate_constant=default_collider,
#     explicit_rate_constants={},
#     collision_efficiencies={},
#     name="H+O2(+M)=HO2(+M)"
# )

# %% [markdown]
# ```bash
# H +O2 (+M) = HO2 +(M) 4.650e+012 0.440 0.0
#   LowMX/1.737e+019 -1.230 0.0/
#   TroeMX/ 6.700e-001 1.000e-030 1.000e+030 1.000e+030/
#   LowSP/ AR 6.810e+018 -1.200 0.0/
#   TroeSP/AR 7.000e-001 1.000e-030 1.000e+030 1.000e+030/
#   LowSP/ HE 9.192e+018 -1.200 0.0/
#   TroeSP/HE 5.900e-001 1.000e-030 1.000e+030 1.000e+030/
#   HE / 1.0 / AR / 1.0 / H2/ 1.30/ H2O/ 10.00 /
# ```

# %%
import jax.numpy as jnp
from diffPLOG2TROE.parametrization import FallOff, CollisionEfficiency, MixtureRule

default_collider = FallOff(
    name="H+O2(+M)=HO2(+M)",
    hpl_parameters={"A": 4.650E+12, "n": 0.44, "Ea": 0.0},
    lpl_parameters={"A": 1.737e19, "n": -1.230, "Ea": 0.0},
    falloff_parameters={"A": 0.67, "T3": 1e-30, "T2": 1e30, "T1": 1e30},
    falloff_type="troe",
    efficiencies=[
        CollisionEfficiency(name="H2", value=1.30),
        CollisionEfficiency(name="H2O", value=10.00),
    ],
)
ar_specific_rate = FallOff(
    name="H+O2(+AR)=HO2(+AR)",
    hpl_parameters={"A": 4.650E+12, "n": 0.44, "Ea": 0.0},
    lpl_parameters={"A": 6.81e18, "n": -1.2, "Ea": 0.0},
    falloff_parameters={"A": 0.7, "T3": 1e-30, "T2": 1e30, "T1": 1e30},
    falloff_type="troe",
)
he_specific_rate = FallOff(
    name="H+O2(+HE)=HO2(+HE)",
    hpl_parameters={"A": 4.650E+12, "n": 0.44, "Ea": 0.0},
    lpl_parameters={"A": 9.192, "n": -1.2, "Ea": 0.0},
    falloff_parameters={"A": 0.59, "T3": 1e-30, "T2": 1e30, "T1": 1e30},
    falloff_type="troe",
)

extended_falloff_reaction = MixtureRule(
    default_rate_constant = default_collider,
    explicit_rate_constants = {
        "Ar": ar_specific_rate,
        "He": he_specific_rate
    },
    efficiencies = [
        CollisionEfficiency(name="H2", value=1.30),
        CollisionEfficiency(name="H2O", value=10.00)
    ],
    linear = True,
    reduced_pressure = False,
    name = "H+O2(+M)=HO2(+M)",
)

T_range = jnp.linspace(300, 3000, 10)
ciao=[]
for t in T_range:
    ciao.append(extended_falloff_reaction.rate_constant(t, 1, {"Ar": 1})/1000)

# %%
import matplotlib.pyplot as plt

cantera=[2.7259679874e+08,6.0742605016e+07,2.5087602864e+07,1.3378300719e+07,8.2105097806e+06,5.5082163591e+06,3.9297872883e+06,2.9329026440e+06,2.2655948312e+06,1.7983309372e+06]
error = []
for i in range(len(cantera)):
    error.append((ciao[i] - cantera[i]) / ciao[i])

fig, axs = plt.subplots(1, 2)

axs[0].plot(T_range, cantera, "ro")
axs[0].plot(T_range, ciao, "bo")
axs[0].set_yscale("log")

axs[1].plot(T_range, error)
axs[1].set_yscale("log")
plt.show()

# %% [markdown]
# ```
# H+O2(+M)=HO2(+M)   1.000          0.000    0.000
# RPBMR  / LINEAR /
#  COLL  / AR        6.2814E+20    -1.770    642.660 /
#   PLOG / 0.10      9.6149E+17    -2.800    739.430 /
#   PLOG / 1.00      8.2354E+18    -2.780    836.070 /
#   PLOG / 10.00     4.9667E+19    -2.719    989.680 /
#   PLOG / 100.00    1.7637E+20    -2.596    1256.89 /
#  COLL  / HE        3.9936E+20    -1.720    631.600 /
#   PLOG / 0.10      8.9016E+17    -2.800    788.800 /
#   PLOG / 1.00      8.1980E+18    -2.790    889.590 /
#   PLOG / 10.00     4.3100E+19    -2.712    1002.67 /
#   PLOG / 100.00    1.3738E+20    -2.576    1232.78 /
#  COLL  / N2        4.6362E+21    -1.977    672.760 /
#   PLOG / 0.10      7.3248E+18    -3.011    793.410 /
#   PLOG / 1.00      6.4063E+19    -2.993    924.010 /
#   PLOG / 10.00     3.7158E+20    -2.926    1134.82 /
#   PLOG / 100.00    1.2397E+21    -2.794    1495.48 /
#  COLL  / H2O       1.1447E+21    -1.417    460.790 /
#   PLOG / 0.10      2.1686E+18    -2.472    687.690 /
#   PLOG / 1.00      1.5935E+19    -2.430    924.830 /
#   PLOG / 10.00     4.4494E+19    -2.272    1260.94 /
#   PLOG / 100.00    1.9898E+19    -1.901    1583.74 /
#  COLL  / CO2       3.1750E+19    -1.087    553.370 /
#   PLOG / 0.10      4.9578E+16    -2.119    681.240 /
#   PLOG / 1.00      3.3623E+17    -2.070    779.670 /
#   PLOG / 10.00     1.1054E+18    -1.937    907.630 /
#   PLOG / 100.00    1.4019E+18    -1.696    1100.28 /
#  COLL  / H2        6.0298E+21    -1.971    699.130 /
#   PLOG / 0.10      9.6838E+18    -3.007    846.490 /
#   PLOG / 1.00      7.4253E+19    -2.973    968.350 /
#   PLOG / 10.00     3.9251E+20    -2.897    1180.78 /
#   PLOG / 100.00    1.1190E+21    -2.747    1539.33 /
#  COLL  / O2        2.2651E+21    -1.954    639.920 /
#   PLOG / 0.10      3.5715E+18    -2.988    747.150 /
#   PLOG / 1.00      3.2142E+19    -2.974    862.190 /
#   PLOG / 10.00     2.0376E+20    -2.918    1042.63 /
#   PLOG / 100.00    7.9974E+20    -2.806    1362.75 /
#  COLL  / DEFAULT   6.2814E+20    -1.770    642.660 /
#   H / 1 / ! CO / 1.900 / CH4 / 2.000 / C2H6 / 3.000 /
#   PLOG / 0.10      9.6149E+17    -2.800    739.430 /
#   PLOG / 1.00      8.2354E+18    -2.780    836.070 /
#   PLOG / 10.00     4.9667E+19    -2.719    989.680 /
#   PLOG / 100.00    1.7637E+20    -2.596    1256.89 /
# ```

# %%
from KiRATE.kinetics import Plog, MixtureRule, CollisionEfficiency

ar_rate = Plog(
    parameters={
        0.10: {"A": 9.6149e17, "n": -2.800, "Ea": 739.430},
        1.00: {"A": 8.2354e18, "n": -2.780, "Ea": 836.070},
        10.00: {"A": 4.9667e19, "n": -2.719, "Ea": 989.680},
        100.00: {"A": 1.7637e20, "n": -2.596, "Ea": 1256.89},
    },
    k0={"A": 6.2814E+20, "n": -1.770, "Ea": 642.660}
)

n2_rate = Plog(
    parameters={
        0.10: {"A": 7.3248e18, "n": -3.011, "Ea": 793.410},
        1.00: {"A": 6.4063e19, "n": -2.993, "Ea": 924.010},
        10.00: {"A": 3.7158e20, "n": -2.926, "Ea": 1134.82},
        100.00: {"A": 1.2397e21, "n": -2.794, "Ea": 1495.48},
    },
    k0={"A": 4.6362E+21, "n": -1.977, "Ea": 672.760}
)

default_rate = Plog(
    parameters={
        0.10: {"A": 9.6149e17, "n": -2.800, "Ea": 739.430},
        1.00: {"A": 8.2354e18, "n": -2.780, "Ea": 836.070},
        10.00: {"A": 4.9667e19, "n": -2.719, "Ea": 989.680},
        100.00: {"A": 1.7637e20, "n": -2.596, "Ea": 1256.89},
    },
    k0={"A": 6.2814E+20, "n": -1.770, "Ea": 642.660}
)

collision_efficiencies = [
    CollisionEfficiency(name="Ar", value=0.5),
    CollisionEfficiency(name="N2", value=1.2),
    CollisionEfficiency(name="H2O", value=12.0),
]

# Create mixture rule with LMR-R
mixture_rule = MixtureRule(
    name="H+O2(+M)=HO2(+M)"
    default_rate_constant=default_rate,
    explicit_rate_constants={"Ar": ar_rate, "N2": n2_rate},
    linear=True,
    reduced_pressure=True,
)

T = 1500.0
P = 1.0
composition = {"Ar": 0.3, "N2": 0.4, "H2O": 0.2, "CO2": 0.1}

# This will automatically call _lmr_r() because reduced_pressure=True
k_mixture = mixture_rule.rate_constant(T, P, composition)

print(k_mixture)
# Out:
# 		0.00000e+00 0.00000 0.00000e+00
#  PLOG / 1.00000e-01	9.61490e+17 -2.80000 7.39430e+02 /
#  PLOG / 1.00000e+00	8.23540e+18 -2.78000 8.36070e+02 /
#  PLOG / 1.00000e+01	4.96670e+19 -2.71900 9.89680e+02 /
#  PLOG / 1.00000e+02	1.76370e+20 -2.59600 1.25689e+03 /
#  ! k0 --> 6.28140e+20 -1.77000 6.42660e+02
# 11340462467.054817

# %% [markdown]
# ```yaml
# - equation: NH3 (+M) <=> H + NH2 (+M)
#   type: linear-Burke
#   colliders:
#   - name: M
#     type: pressure-dependent-Arrhenius
#     rate-constants:
#     - {P: 0.1 atm, A: 7.23e+29, b: -5.316, Ea: 110862.4}
#     - {P: 1 atm, A: 3.497e+30, b: -5.224, Ea: 111163.3}
#     - {P: 10 atm, A: 1.975e+31, b: -5.155, Ea: 111887.8}
#     - {P: 100 atm, A: 2.689e+31, b: -4.920, Ea: 112778.7}
#   - name: N2
#     efficiency: {A: 4.49281e+00, b: -9.46265e-02, Ea: -1.10071e+02}
#   - name: O2
#     efficiency: {A: 1.15210e-01, b: 3.41234e-01, Ea: -3.89210e+02}
#   - name: CO2
#     efficiency: {A: 9.19583e+00, b: 6.10696e-02, Ea: 9.01088e+01}
#   - name: NH3
#     efficiency: {A: 1.49004e+01, b: 6.06535e-02, Ea: 2.47652e+02}
#   - name: H2O
#     efficiency: {A: 1.14560e+01, b: 1.27501e-01, Ea: 3.13959e+02}
# ```

# %%
from KiRATE.kinetics import Plog, CollisionEfficiency

n2 = CollisionEfficiency(name="N2", param)

# %%
help(CollisionEfficiency)
# Out:
# Help on class CollisionEfficiency in module KiRATE.kinetics.collision_efficiency:
#
# class CollisionEfficiency(equinox._module.Module)
#  |  CollisionEfficiency(
#  |      name: str = 'M',
#  |      *,
#  |      value: Optional[jaxtyping.Float64] = None,
#  |      arrhenius_parameters: Optional[Dict[str, jaxtyping.Float64]] = None
#  |  ) -> None
#  |
#  |  Represents collision efficiency for a species in pressure-dependent reactions.
#  |
#  |  Collision efficiency can be either:
#  |  1. Constant value (temperature-independent)
#  |  2. Temperature-dependent following Arrhenius-like form: A * T^n * exp(-Ea/(R*T))
#  |
#  |  Args:
#  |      name: Species name (e.g., "H2", "CO", "M")
#  |      value: Temperature-independent collision efficiency value
#  |      arrhenius_parameters: Dict with keys "A", "n", "Ea" for temperature dependence
#  |
#  |  Example:
#  |      # Constant efficiency
#  |      eff1 = CollisionEfficiency(name="CO", value=2.0)
#  |
# ...
