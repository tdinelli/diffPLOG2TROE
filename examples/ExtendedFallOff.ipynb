# %%
rate_constant_N2 = FallOff(
    FallOff(
    name="",
    hpl_parameters=[],
    lpl_parameters=[],
    falloff_parameters=[],
    falloff_type="troe",
)

rate_constant = ExtendedFallOff(
    name="",
    hplmix_parameters=[],
    lplmix_parameters=[],
    falloffmix_parameters=[],
    explicit_colliders={
        "N2": rate_constant_N2
    }
    falloff_type="troe",
    efficiencies={"H2": 2, "CO": 2, "CO2": 3, "H2O": 5},
)
