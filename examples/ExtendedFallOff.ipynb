# %%
import jax.numpy as jnp
from diffPLOG2TROE.parametrization import CollisionEfficiency

Theff_He  = CollisionEfficiency(parameters=jnp.array([3.37601e-01,  1.82568e-01,  3.62408e+01]), name="He")
Norm_H2O  = CollisionEfficiency(parameters=17.5, name="H2O")

print(Theff_He())
print(Norm_H2O())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 Theff_He  = CollisionEfficiency(parameters=jnp.array([3.37601e-01,  1.82568e-01,  3.62408e+01]), name="He")
#       5 Norm_H2O  = CollisionEfficiency(parameters=17.5, name="H2O")
# ----> 7 print(Theff_He())
#       8 print(Norm_H2O())
#
# File ~/Documents/GitHub/diffPLOG2TROE/diffPLOG2TROE/parametrization/collision_efficiency.py:34, in CollisionEfficiency.__call__(self, T)
#      32     return self.lnA
#      33 else:
# ---> 34     return self.arrhenius_like(T)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/plog/lib/python3.13/site-packages/equinox/_module.py:1182, in Partial.__call__(self, *args, **kwargs)
#    1169 def __call__(self, *args, **kwargs):
#    1170     """Call the wrapped `self.func`.
#    1171
#    1172     **Arguments:**
#    (...)   1180     The result of the wrapped function.
#    1181     """
# -> 1182     return self.func(*self.args, *args, **kwargs, **self.keywords)
#
#     [... skipping hidden 19 frame]
#
# File ~/Documents/GitHub/diffPLOG2TROE/diffPLOG2TROE/parametrization/collision_efficiency.py:38, in CollisionEfficiency.arrhenius_like(self, T)
#      36 @eqx.filter_jit
#      37 def arrhenius_like(self, T: ScalarOrVector) -> ScalarOrVector:
# ---> 38     return jnp.exp(self.lnA + self.n * jnp.log(T) - self.EaR / T)
#
#     [... skipping hidden 14 frame]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/plog/lib/python3.13/site-packages/jax/_src/numpy/ufuncs.py:489, in log(x)
#     454 @export
#     455 @partial(jit, inline=True)
#     456 def log(x: ArrayLike, /) -> Array:
#     457   """Calculate element-wise natural logarithm of the input.
#     458
#     459   JAX implementation of :obj:`numpy.log`.
#    (...)    487     Array(True, dtype=bool)
#     488   """
# --> 489   return lax.log(*promote_args_inexact('log', x))
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/plog/lib/python3.13/site-packages/jax/_src/numpy/util.py:241, in promote_args_inexact(fun_name, *args)
#     237 def promote_args_inexact(fun_name: str, *args: ArrayLike) -> list[Array]:
#     238   """Convenience function to apply Numpy argument shape and dtype promotion.
#     239
#     240   Promotes non-inexact types to an inexact type."""
# --> 241   check_arraylike(fun_name, *args)
#     242   _check_no_float0s(fun_name, *args)
#     243   check_for_prngkeys(fun_name, *args)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/plog/lib/python3.13/site-packages/jax/_src/numpy/util.py:181, in check_arraylike(fun_name, emit_warning, stacklevel, *args)
#     178   warnings.warn(msg + " In a future JAX release this will be an error.",
#     179                 category=DeprecationWarning, stacklevel=stacklevel)
#     180 else:
# --> 181   raise TypeError(msg.format(fun_name, type(arg), pos))
#
# TypeError: log requires ndarray or scalar arguments, got <class 'NoneType'> at position 0.

# %% [markdown]
# ```bash
# - equation: H + O2 (+M) <=> HO2 (+M) # Adding '(+M)' is optional
#   type: linear-Burke
#   colliders:
#   - name: M
#     type: pressure-dependent-Arrhenius
#     rate-constants:
#     - {P: 1.316e-02 atm, A: 9.39968e+14, b: -2.14348e+00, Ea: 7.72730e+01}
#     - {P: 1.316e-01 atm, A: 1.07254e+16, b: -2.15999e+00, Ea: 1.30239e+02}
#     - {P: 3.947e-01 atm, A: 3.17830e+16, b: -2.15813e+00, Ea: 1.66994e+02}
#     - {P: 1.000e+00 atm, A: 7.72584e+16, b: -2.15195e+00, Ea: 2.13473e+02}
#     - {P: 3.000e+00 atm, A: 2.11688e+17, b: -2.14062e+00, Ea: 2.79031e+02}
#     - {P: 1.000e+01 atm, A: 6.53093e+17, b: -2.13213e+00, Ea: 3.87493e+02}
#     - {P: 3.000e+01 atm, A: 1.49784e+18, b: -2.10026e+00, Ea: 4.87579e+02}
#     - {P: 1.000e+02 atm, A: 3.82218e+18, b: -2.07057e+00, Ea: 6.65984e+02}
#   - name: HE
#     efficiency: {A: 3.37601e-01, b: 1.82568e-01, Ea: 3.62408e+01}
#   - name: N2
#     efficiency: {A: 1.24932e+02, b: -5.93263e-01, Ea: 5.40921e+02}
#   - name: H2
#     efficiency: {A: 3.13717e+04, b: -1.25419e+00, Ea: 1.12924e+03}
#   - name: CO2
#     efficiency: {A: 1.62413e+08, b: -2.27622e+00, Ea: 1.97023e+03}
#   - name: NH3
#     efficiency: {A: 4.97750e+00, b: 1.64855e-01, Ea: -2.80351e+02}
#   - name: H2O
#     efficiency: {A: 3.69146e+01, b: -7.12902e-02, Ea: 3.19087e+01}
# ```

# %%
default = Plog(
    parameters=jnp.array([
        [1.316e-02, 9.39968e+14, -2.14348e+00, 7.72730e+01],
        [1.316e-01, 1.07254e+16, -2.15999e+00, 1.30239e+02],
        [3.947e-01, 3.17830e+16, -2.15813e+00, 1.66994e+02],
        [1.000e+00, 7.72584e+16, -2.15195e+00, 2.13473e+02],
        [3.000e+00, 2.11688e+17, -2.14062e+00, 2.79031e+02],
        [1.000e+01, 6.53093e+17, -2.13213e+00, 3.87493e+02],
        [3.000e+01, 1.49784e+18, -2.10026e+00, 4.87579e+02],
        [1.000e+02, 3.82218e+18, -2.07057e+00, 6.65984e+02],
    ]),
)

Theff_He  = CollisionEfficiency(parameters=jnp.array([3.37601e-01,  1.82568e-01,  3.62408e+01]), name="He")
Theff_N2  = CollisionEfficiency(parameters=jnp.array([1.24932e+02, -5.93263e-01,  5.40921e+02]), name="N2")
Theff_H2  = CollisionEfficiency(parameters=jnp.array([3.13717e+04, -1.25419e+00,  1.12924e+03]), name="H2")
Theff_CO2 = CollisionEfficiency(parameters=jnp.array([1.62413e+08, -2.27622e+00,  1.97023e+03]), name="CO2")
Theff_NH3 = CollisionEfficiency(parameters=jnp.array([4.97750e+00,  1.64855e-01, -2.80351e+02]), name="NH3")
Theff_H2O = CollisionEfficiency(parameters=jnp.array([3.69146e+01, -7.12902e-02,  3.19087e+01]), name="H2O")

rate_constant = LinearMixtureRule(
    # Default collider section
    default_rate_constant=default,
    # Explicit colliders section
    explicit_rate_constants={
    },
    # Explicit efficiencies for colliders where the rate constant is not defined
    collision_efficiencies={
    },
    name="H+O2(+M)=HO2(+M)"
)
